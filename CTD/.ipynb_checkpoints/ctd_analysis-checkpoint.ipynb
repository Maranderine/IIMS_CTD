# %% [markdown]
# # CTD / Glider Data Analysis
# **IIMS Sensor Processing Project — WS 2025/26**
#
# Dataset: SLOCUM G3 glider, Atlantic Ocean
# Task: Identify structure of density distribution
#
# ---
# Sections:
# 1. Setup & data loading
# 2. Data inspection
# 3. Preprocessing & derived variables
# 4. Profile plotter (single dive)
# 5. Section plotter (2D transect)
# 6. T-S diagram
# 7. Buoyancy frequency N²

# %%
import numpy as np
import pandas as pd 
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import cmocean
import gsw
from scipy.ndimage import gaussian_filter1d

plt.rcParams.update({'figure.dpi': 120, 'font.size': 11})

# %% [markdown]
# ## 1 — Data loading
#
# | column | unit | description |
# |--------|------|-------------|
# | `time` | datetime64 | UTC timestamp |
# | `lat` | °N | latitude |
# | `lon` | °E | longitude |
# | `depth` | m (positive down) | depth |
# | `pressure` | bar | measured pressure |
# | `temperature` | °C | in-situ temperature |
# | `conductivity` | S/m | conductivity |

# %%
# ── SET YOUR FILE PATH ──────────────────────────────────────────────────────
NC_FILE = 'data/GliderIFM16_CTD.nc'

# ── Open and inspect ────────────────────────────────────────────────────────
ds = xr.open_dataset(NC_FILE)
print("Dimensions:", dict(ds.sizes))
print("Variables :", list(ds.data_vars))
for var in ds.data_vars:
    print(f"  - {var}: [{ds[var].attrs.get('units', 'No units')}]")
# Out:
# Dimensions: {'time': 313538}
# Variables : ['lat', 'lon', 'depth', 'conductivity', 'temperature', 'pressure']
#   - lat: [decimal degrees]
#   - lon: [decimal degrees]
#   - depth: [m]
#   - conductivity: [S/m]
#   - temperature: [degC]
#   - pressure: [Bar]

# %% [markdown]
# ## 2 — Data inspection

# %%
ds['lat'] = ds['lat'].where(xr.ufuncs.abs((ds['lat'])) <= 90)  # Replace 0 with NaN for interpolation
print("Missing latitude values:", ds['lat'].isnull().sum())

ds['lon'] = ds['lon'].where(xr.ufuncs.abs((ds['lon'])) <= 180)  # Replace 0 with NaN for interpolation
print("Missing longitude values:", ds['lon'].isnull().sum())

print("Latitude range:", ds['lat'].min().item(), "to", ds['lat'].max().item())
print("Longitude range:", ds['lon'].min().item(), "to", ds['lon'].max().item()) 

df = pd.DataFrame({
    'time':        pd.to_datetime(ds['time'].values, unit='s'),
    'lat':         ds['lat'].values.astype(float),
    'lon':         ds['lon'].values.astype(float),
    'depth':       ds['depth'].values.astype(float),
    'pressure':    ds['pressure'].values.astype(float),
    'temperature': ds['temperature'].values.astype(float),
})

cond = ds['conductivity'].values.astype(float)

# conductivity in S/m but gsw.SP_from_C exspects mS/cm => ×10
cond = cond * 10
print("Conductivity converted from S/m to mS/cm")
df['salinity'] = gsw.SP_from_C(cond, df['temperature'], df['pressure'])
print("Salinity derived from conductivity via gsw.SP_from_C")
    
# Drop rows with missing values
df = df.dropna(subset=['depth', 'temperature', 'salinity']).reset_index(drop=True)

df['lat'] = df['lat'].interpolate(method='linear')
df['lon'] = df['lon'].interpolate(method='linear')
df = df.sort_values('time').reset_index(drop=True)

# ── Pressure unit guard: SLOCUM sometimes stores pressure in bar not dbar ───
df['pressure'] *= 10
print("pressure converted from bar to dbar")



print(f"\nLoaded {len(df):,} measurements across ")
# Out:
# Missing latitude values: <xarray.DataArray 'lat' ()> Size: 8B
# array(8927)
# Attributes:
#     units:    decimal degrees
# Missing longitude values: <xarray.DataArray 'lon' ()> Size: 8B
# array(8927)
# Attributes:
#     units:    decimal degrees
# Latitude range: 46.625946044921875 to 46.997676849365234
# Longitude range: -42.437103271484375 to -41.40202713012695
# Conductivity converted from S/m to mS/cm
# Salinity derived from conductivity via gsw.SP_from_C
# pressure converted from bar to dbar
#
# Loaded 313,538 measurements across

# %%
print(df.dtypes)
print(df[['depth', 'pressure', 'temperature', 'salinity', 'lon', 'lat']].describe().round(3))
# Out:
# time           datetime64[s]
# lat                  float64
# lon                  float64
# depth                float64
# pressure             float64
# temperature          float64
# salinity             float64
# dtype: object
#             depth    pressure  temperature    salinity         lon         lat
# count  313538.000  313538.000   313538.000  313538.000  313538.000  313538.000
# mean      489.998     490.560        5.526      35.062     -41.727      46.781
# std       286.604     287.541        2.469       0.399       0.228       0.104
# min         0.004       0.220        3.684      32.419     -42.437      46.626
# 25%       242.089     241.750        4.216      35.012     -41.877      46.702
# 50%       485.426     485.415        4.681      35.179     -41.651      46.740
# 75%       736.905     738.050        5.587      35.290     -41.570      46.880
# max       991.735     994.750       18.733      35.914     -41.402      46.998

# %%
# ── Aggregate duplicate timestamps (multiple measurements per 2-minute burst) ────────────
# The GPCTD collects ~128 samples per burst at 1Hz, then pauses (duty cycle sampling)
# All samples within a burst share the same timestamp. Aggregate by taking median values.

print(f"Measurements before aggregation: {len(df):,}")
n_duplicates_before = df['time'].duplicated().sum()
print(f"Duplicate timestamps: {n_duplicates_before}")

# Group by time and aggregate numeric columns with median
numeric_cols = df.select_dtypes(include=[np.number]).columns
df = df.groupby('time')[numeric_cols].median().reset_index()

print(f"Measurements after aggregation: {len(df):,}")
print(f"Unique timestamps: {len(df)}")
print(f"Mean time resolution: {df['time'].diff().dt.total_seconds().median() / 60:.1f} minutes")

# %% [markdown]
# ## Glider Trajectory

# %%
import matplotlib.dates as mdates

# only take measurements at the surface (depth < 2m) with valid GPS
surf_mask = (ds['depth'].values < 2) & (~np.isnan(ds['lat'].values) & ~np.isnan(ds['lon'].values))
lat  = ds['lat'].values[surf_mask]
lon  = ds['lon'].values[surf_mask]
time = ds['time'].values[surf_mask]          # Unix seconds

#changes = np.concatenate([[True], np.diff(lat) != 0])
#lat, lon, time = lat[changes], lon[changes], time[changes]

time_dt  = pd.to_datetime(time, unit='s')
time_num = mdates.date2num(time_dt.to_pydatetime())  # float matplotlib needs

fig, ax = plt.subplots(figsize=(7, 6))
sc = ax.scatter(lon, lat, c=time_num, cmap='plasma', s=20, zorder=3)
ax.plot(lon, lat, lw=0.5, color='grey', zorder=2)
cbar = plt.colorbar(sc, ax=ax)
cbar.ax.yaxis_date()
cbar.ax.yaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
ax.set_xlabel('Longitude (°E)')
ax.set_ylabel('Latitude (°N)')
ax.set_title('Glider trajectory (GPS fixes at surface)')
ax.grid(alpha=0.3)
plt.tight_layout()

# %% [markdown]
# to put trajectory in context, load dataset with geostrophic currentin this region/ at this time and visualize

# %%
import copernicusmarine

# already downloaded. dataset for geostrophic current comparison
""" copernicusmarine.subset(
    dataset_id="cmems_obs-sl_glo_phy-ssh_nrt_allsat-l4-duacs-0.125deg_P1D",
    variables=["sla", "ugos", "vgos"],
    minimum_latitude=46.0,   maximum_latitude=48.0,
    minimum_longitude=-43.0, maximum_longitude=-41.0,
    start_datetime="2025-08-11T00:00:00",
    end_datetime="2025-08-18T00:00:00",
    output_filename="cmems_sla.nc",
    output_directory=".",
    force_download=True
) """
ds_cmems = xr.open_dataset("cmems_sla.nc")

# %%
print("cmes dataset id: ", ds_cmems)
# Out:
# cmes dataset id:  <xarray.Dataset> Size: 49kB
# Dimensions:    (time: 8, latitude: 16, longitude: 16)
# Coordinates:
#   * time       (time) datetime64[ns] 64B 2025-08-11 2025-08-12 ... 2025-08-18
#   * latitude   (latitude) float32 64B 46.06 46.19 46.31 ... 47.69 47.81 47.94
#   * longitude  (longitude) float32 64B -42.94 -42.81 -42.69 ... -41.19 -41.06
# Data variables:
#     sla        (time, latitude, longitude) float64 16kB 0.4458 0.4642 ... 0.1366
#     ugos       (time, latitude, longitude) float64 16kB 0.9027 0.8553 ... 0.4173
#     vgos       (time, latitude, longitude) float64 16kB 0.4157 0.3509 ... 0.8318
# Attributes: (12/45)
#     Conventions:                     CF-1.6
#     Metadata_Conventions:            Unidata Dataset Discovery v1.0
#     cdm_data_type:                   Grid
#     comment:                         Sea Surface Height measured by Altimetry...
#     contact:                         servicedesk.cmems@mercator-ocean.eu
# ...

# %%
import matplotlib.dates as mdates

fig, ax = plt.subplots(figsize=(9, 7))

# --- SLA background (mean over deployment period) ---
sla_mean = ds_cmems['sla'].mean(dim='time')
lon_c = ds_cmems['longitude'].values
lat_c = ds_cmems['latitude'].values

cf = ax.contourf(lon_c, lat_c, sla_mean, levels=20, cmap='RdBu_r', extend='both')
plt.colorbar(cf, ax=ax, label='SLA (m)', shrink=0.7)
ax.contour(lon_c, lat_c, sla_mean, levels=10, colors='k', linewidths=0.3, alpha=0.4)

# --- Geostrophic current vectors ---
u = ds_cmems['ugos'].mean(dim='time').values
v = ds_cmems['vgos'].mean(dim='time').values
skip = 1   # increase if too cluttered
#ax.quiver(lon_c[::skip], lat_c[::skip],
 #         u[::skip, ::skip], v[::skip, ::skip],
  #        scale=3, width=0.004, color='k', alpha=0.6)

ax.streamplot(lon_c, lat_c, u, v, color='k', linewidth=0.6,
              density=1.5, arrowsize=0.8)


# --- Glider trajectory ---
surf_mask = (ds['depth'].values < 2) & (~np.isnan(ds['lat'].values))
glat = ds['lat'].values[surf_mask]
glon = ds['lon'].values[surf_mask]
gtime = ds['time'].values[surf_mask]
gtime_dt = pd.to_datetime(gtime, unit='s')
gtime_num = mdates.date2num(gtime_dt.to_pydatetime())

ax.plot(glon, glat, lw=1, color='white', zorder=4, alpha=0.8)
sc = ax.scatter(glon, glat, c=gtime_num, cmap='plasma', s=30,
                edgecolors='white', linewidths=0.4, zorder=5)
cbar2 = plt.colorbar(sc, ax=ax, shrink=0.7)
cbar2.ax.yaxis_date()
cbar2.ax.yaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
cbar2.set_label('Glider time')

ax.set_xlabel('Longitude (°E)')
ax.set_ylabel('Latitude (°N)')
ax.set_title('Mean SLA + geostrophic currents (Aug 11–18, 2025)')
ax.grid(alpha=0.3)
plt.tight_layout()

# %%
# Quick sanity plots — raw time series of T and S
fig, axes = plt.subplots(2, 1, figsize=(12, 5), sharex=True)
axes[0].scatter(df['time'], df['temperature'], c=df['depth'], cmap=cmocean.cm.deep,
                s=1, rasterized=True)
axes[0].set_ylabel('Temperature (°C)')
axes[1].scatter(df['time'], df['salinity'], c=df['depth'], cmap=cmocean.cm.deep,
                s=1, rasterized=True)
axes[1].set_ylabel('Salinity (PSU)')
axes[1].set_xlabel('Time')
fig.suptitle('Raw time series (colour = depth)')
plt.tight_layout()

# %% [markdown]
# Temperature (top panel):
#
# Deep water (dark blue) stays consistently ~4–5°C the whole time — stable bottom water mass
# Surface temperature (yellow-green) starts at ~15–17°C early on and drops to ~7–8°C by the end — the glider moved into progressively cooler surface waters as it traveled, consistent with the westward drift in the trajectory toward the anticyclone boundary
#
# Salinity (bottom panel):
#
# Deep water consistently ~35.0–35.1 PSU
# Surface dips to ~33–34 PSU — a fresher surface layer typical of North Atlantic (net precipitation, river outflow from NAC)
# The salinity range stays tight (~33–36 PSU), no extreme outliers → outlier removal worked

# %%
# T and S vs depth, coloured by time to show evolution along the mission
t_num = df['time'].astype(np.int64)
t_norm = (t_num - t_num.min()) / (t_num.max() - t_num.min())

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 6), sharey=True)

sc1 = ax1.scatter(df['temperature'], df['depth'], c=t_norm, cmap='plasma',
                  s=1, alpha=0.3, rasterized=True)
plt.colorbar(sc1, ax=ax1, label='Time (early → late)')
ax1.set_xlabel('Temperature (°C)')
ax1.set_ylabel('Depth (m)')
ax1.invert_yaxis()
ax1.set_title('Temperature vs depth')
ax1.grid(alpha=0.3)

sc2 = ax2.scatter(df['salinity'], df['depth'], c=t_norm, cmap='plasma',
                  s=1, alpha=0.3, rasterized=True)
plt.colorbar(sc2, ax=ax2, label='Time (early → late)')
ax2.set_xlabel('Salinity (PSU)')
ax2.set_title('Salinity vs depth')
ax2.grid(alpha=0.3)

plt.tight_layout()

# %% [markdown]
# ## assigning dive id

# %%
test = df.iloc[:100].copy()  # Take every 10th point for faster testing

# ── Assign dive_id ──────────────────────────────────────────────────────────
z = test['depth'].values
dz = np.sign(np.diff(z, prepend=z[0]))
dz_smooth = pd.Series(dz).rolling(3, center=True, min_periods=1).median().values
going_down = dz > 0
test['dive_id'] = np.cumsum(np.diff(going_down.astype(int), prepend=0) > 0)
print("dive_id assigned from depth direction changes")

fig, ax = plt.subplots(figsize=(12, 3))
ax.scatter(test['time'], test['pressure'], s=1, c=test['dive_id'], alpha=0.3, rasterized=True)
ax.set_ylabel('Depth (m)')
ax.set_xlabel('Time')
ax.invert_yaxis()
ax.set_title('Depth over time — red marks = start of each dive_id')
plt.tight_layout()
# Out:
# dive_id assigned from depth direction changes

# %% [markdown]
# ## 3 — Preprocessing & derived variables

# %%
# ── Outlier removal (simple IQR filter per variable) ───────────────────────
def iqr_filter(series, k=3.0):
    q1, q3 = series.quantile([0.25, 0.75])
    iqr = q3 - q1
    return series.between(q1 - k * iqr, q3 + k * iqr)

mask = iqr_filter(df['temperature']) & iqr_filter(df['salinity'])
n_removed = (~mask).sum()
df_outliers = df[~mask].copy()
df = df[mask].copy()
print(f"Removed {n_removed} outliers ({n_removed/len(mask)*100:.2f}%)")
# Out:
# Removed 151 outliers (0.05%)

# %%
# Kept data (grey) vs removed outliers (red) for temperature and salinity
fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

axes[0].scatter(df['temperature'],         df['depth'], s=1, c='steelblue',
                alpha=0.2, rasterized=True, label=f'kept ({len(df):,})')
axes[0].scatter(df_outliers['temperature'], df_outliers['depth'], s=4, c='red',
                alpha=0.6, rasterized=True, label=f'removed ({len(df_outliers):,})')
axes[0].set_xlabel('Temperature (°C)')
axes[0].set_ylabel('Depth (m)')
axes[0].invert_yaxis()
axes[0].legend(markerscale=4)
axes[0].grid(alpha=0.3)

axes[1].scatter(df['salinity'],         df['depth'], s=1, c='steelblue',
                alpha=0.2, rasterized=True, label=f'kept ({len(df):,})')
axes[1].scatter(df_outliers['salinity'], df_outliers['depth'], s=4, c='red',
                alpha=0.6, rasterized=True, label=f'removed ({len(df_outliers):,})')
axes[1].set_xlabel('Salinity (PSU)')
axes[1].legend(markerscale=4)
axes[1].grid(alpha=0.3)

fig.suptitle('Outlier removal — kept (blue) vs removed (red)')
plt.tight_layout()

# %%
# ── Derived variables via gsw (TEOS-10) ────────────────────────────────────

# Absolute Salinity and Conservative Temperature (TEOS-10 standards)
df['SA'] = gsw.SA_from_SP(df['salinity'], df['pressure'], df['lon'], df['lat'])
df['CT'] = gsw.CT_from_t(df['SA'], df['temperature'], df['pressure'])

# Potential density anomaly σ₀ = ρ(SA, CT, p=0) − 1000  [kg/m³]
df['sigma0'] = gsw.sigma0(df['SA'], df['CT'])

# In-situ density (for N² calculation)
df['rho'] = gsw.rho(df['SA'], df['CT'], df['pressure'])

print(df[['SA', 'CT', 'sigma0', 'rho']].describe().round(4))
# Out:
#                 SA           CT       sigma0          rho
# count  313538.0000  313538.0000  313538.0000  313538.0000
# mean       35.2298       5.4808      27.6366    1029.8930
# std         0.4018       2.4855       0.6267       1.8295
# min        32.5723       3.6020      23.5812    1023.5844
# 25%        35.1791       4.1493      27.5559    1028.6529
# 50%        35.3470       4.6330      27.8372    1030.0712
# 75%        35.4597       5.5570      27.9855    1031.3827
# max        36.0840      18.7785      28.1255    1032.6927

# %%
# ── Assign distance along track (km from first dive) ──────────────────────
lat0 = df['lat'].min()
lon0 = df['lon'].iloc[0]
# simple flat-Earth approximation; replace with gsw.distance for accuracy
df['dist_km'] = gsw.distance(
    np.column_stack([df['lon'], df['lat']]),
    axis=0
).cumsum()[0] / 1000 if False else (
    # fallback: degrees * 111 km/deg
    np.sqrt(((df['lat'] - lat0) * 111)**2 + ((df['lon'] - lon0) * 111 * np.cos(np.radians(lat0)))**2)
)
print(f"Section length: {df['dist_km'].max():.1f} km")
# Out:
# Section length: 59.0 km

# %% [markdown]
# ## 4 — Profile plotter (single dive)

# %%
def plot_profile(df, dive_id, smooth_sigma=2):
    """T, S, σ₀ vs depth for one dive."""
    d = df[df['dive_id'] == dive_id].sort_values('depth')

    T = gaussian_filter1d(d['temperature'].values, smooth_sigma)
    S = gaussian_filter1d(d['salinity'].values, smooth_sigma)
    sig = gaussian_filter1d(d['sigma0'].values, smooth_sigma)
    z = d['depth'].values

    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(10, 7), sharey=True)

    ax1.plot(T, z, color=cmocean.cm.thermal(0.7), lw=1.5)
    ax1.set_xlabel('Temperature (°C)')
    ax1.set_ylabel('Depth (m)')
    ax1.invert_yaxis()
    ax1.grid(alpha=0.3)

    ax2.plot(S, z, color=cmocean.cm.haline(0.6), lw=1.5)
    ax2.set_xlabel('Salinity (PSU)')
    ax2.grid(alpha=0.3)

    ax3.plot(sig, z, color='k', lw=1.5)
    ax3.set_xlabel('σ₀ (kg/m³)')
    ax3.grid(alpha=0.3)

    lat = d['lat'].iloc[0]
    fig.suptitle(f'Dive {dive_id} — {lat:.2f}°N')
    plt.tight_layout()
    return fig

# ── Change dive_id to inspect different dives ──────────────────────────────
DIVE_TO_PLOT = 5
fig = plot_profile(df, DIVE_TO_PLOT)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 33
#      29     return fig
#      30
#      31 # ── Change dive_id to inspect different dives ──────────────────────────────
#      32 DIVE_TO_PLOT = 5
# ---> 33 fig = plot_profile(df, DIVE_TO_PLOT)
#
# Cell In[14], line 26, in plot_profile(df, dive_id, smooth_sigma)
#      22     ax3.plot(sig, z, color='k', lw=1.5)
#      23     ax3.set_xlabel('σ₀ (kg/m³)')
#      24     ax3.grid(alpha=0.3)
#      25
# ---> 26     lat = d['lat'].iloc[0]
#      27     fig.suptitle(f'Dive {dive_id} — {lat:.2f}°N')
#      28     plt.tight_layout()
#      29     return fig
#
# File ~/Sync/Studium/STOFF/SoSe26/IMASYS/IMS_env/lib/python3.14/site-packages/pandas/core/indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
# ...

# %% [markdown]
# ## 5 — Section plotter (2D transect)

# %%
def make_section_grid(df, var, depth_bins=None, x_col='lat'):
    """Bin data onto a regular depth × position grid for section plots."""
    if depth_bins is None:
        depth_bins = np.arange(0, df['depth'].max() + 10, 10)

    x_vals = sorted(df[x_col].unique())
    grid = np.full((len(depth_bins) - 1, len(x_vals)), np.nan)

    for j, x in enumerate(x_vals):
        col = df[df[x_col] == x].copy()
        for i in range(len(depth_bins) - 1):
            mask = (col['depth'] >= depth_bins[i]) & (col['depth'] < depth_bins[i + 1])
            if mask.any():
                grid[i, j] = col.loc[mask, var].mean()

    depth_centres = 0.5 * (depth_bins[:-1] + depth_bins[1:])
    return grid, depth_centres, np.array(x_vals)


def plot_section(df, var, cmap, label, vmin=None, vmax=None,
                 depth_bins=None, x_col='lat', x_label='Latitude (°N)'):
    grid, depths, x_vals = make_section_grid(df, var, depth_bins, x_col)

    fig, ax = plt.subplots(figsize=(12, 5))
    im = ax.pcolormesh(
        x_vals, depths, grid,
        cmap=cmap, vmin=vmin, vmax=vmax,
        shading='auto'
    )
    plt.colorbar(im, ax=ax, label=label, pad=0.02)
    ax.set_xlabel(x_label)
    ax.set_ylabel('Depth (m)')
    ax.invert_yaxis()
    ax.set_title(f'{label} — Atlantic section')
    plt.tight_layout()
    return fig

#vmin=df['temperature'].quantile(0.02), vmax=df['temperature'].quantile(0.98)

# %%
# Temperature section
plot_section(df, 'temperature', cmocean.cm.thermal, 'Temperature (°C)',
             vmin=2, vmax=26, depth_bins=np.arange(0, df['depth'].max() + 100, 100), x_col='lat', x_label='Latitude (°N)' )

# %%
# Salinity section
plot_section(df, 'salinity', cmocean.cm.haline, 'Salinity (PSU)',
             vmin=34.5, vmax=36.8)

# %%
# Density anomaly σ₀ section
plot_section(df, 'sigma0', cmocean.cm.dense, 'σ₀ (kg/m³)',
             vmin=24, vmax=28)

# %% [markdown]
# ## 6 — T-S diagram (water mass identification)

# %%
# Longitude vs depth with temperature contours (optimized)
depth_bins = np.arange(0, df['depth'].max() + 20, 20)  # Coarser binning for speed
grid_temp, depths_temp, lon_vals = make_section_grid(df, 'temperature', depth_bins=depth_bins, x_col='lon')

fig, ax = plt.subplots(figsize=(12, 5))

# Pcolormesh for background temperature field
im = ax.pcolormesh(
    lon_vals, depths_temp, grid_temp,
    cmap=cmocean.cm.thermal,
    vmin=2, vmax=26,
    shading='auto'
)
plt.colorbar(im, ax=ax, label='Temperature (°C)', pad=0.02)

# Add contour lines for temperature (isotherms)
contour_levels = np.arange(2, 27, 2)  # Contours every 2°C
cs = ax.contour(lon_vals, depths_temp, grid_temp,
                levels=contour_levels, colors='white', linewidths=0.8, alpha=0.6)
ax.clabel(cs, fmt='%.0f°C', fontsize=8, inline=True)

ax.set_xlabel('Longitude (°E)')
ax.set_ylabel('Depth (m)')
ax.invert_yaxis()
ax.set_title('Temperature section — Longitude vs Depth with Isotherms')
ax.grid(alpha=0.2, linestyle='--', color='gray')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[87], line 3
#       1 # Longitude vs depth with temperature contours (optimized)
#       2 depth_bins = np.arange(0, df['depth'].max() + 20, 20)  # Coarser binning for speed
# ----> 3 grid_temp, depths_temp, lon_vals = make_section_grid(df, 'temperature', depth_bins=depth_bins, x_col='lon')
#       4
#       5 fig, ax = plt.subplots(figsize=(12, 5))
#       6
#
# Cell In[85], line 12, in make_section_grid(df, var, depth_bins, x_col)
#       8
#       9     for j, x in enumerate(x_vals):
#      10         col = df[df[x_col] == x].copy()
#      11         for i in range(len(depth_bins) - 1):
# ---> 12             mask = (col['depth'] >= depth_bins[i]) & (col['depth'] < depth_bins[i + 1])
#      13             if mask.any():
#      14                 grid[i, j] = col.loc[mask, var].mean()
#      15
#
# ...

# %%
# ── Isopycnal contours (σ₀ lines) ─────────────────────────────────────────
T_range = np.linspace(df['CT'].min() - 1, df['CT'].max() + 1, 200)
S_range = np.linspace(df['SA'].min() - 0.2, df['SA'].max() + 0.2, 200)
T_grid, S_grid = np.meshgrid(T_range, S_range)
sigma_grid = gsw.sigma0(S_grid, T_grid)

fig, ax = plt.subplots(figsize=(7, 7))

# Scatter coloured by depth
sc = ax.scatter(
    df['SA'], df['CT'],
    c=df['depth'], cmap=cmocean.cm.deep,
    s=1, alpha=0.4, rasterized=True
)
plt.colorbar(sc, ax=ax, label='Depth (m)')

# Isopycnals
sigma_levels = np.arange(24, 29, 0.5)
cs = ax.contour(S_grid, T_grid, sigma_grid,
                levels=sigma_levels, colors='grey', linewidths=0.8, alpha=0.7)
ax.clabel(cs, fmt='σ₀=%.1f', fontsize=8)

# Water mass labels (approximate Atlantic values — adjust to your data)
water_masses = {
    'AAIW':  (34.2, 4.5),    # S~34.2, T~4.5°C, ~800m
    'NADW':  (34.95, 3.0),   # S~34.95, T~3°C, ~2000m
    'AABW':  (34.68, 0.5),   # S~34.68, T<1°C, >4000m
}
for name, (s, t) in water_masses.items():
    ax.annotate(name, xy=(s, t), fontsize=9, color='navy',
                bbox=dict(boxstyle='round,pad=0.2', fc='white', alpha=0.7))

ax.set_xlabel('Absolute Salinity SA (g/kg)')
ax.set_ylabel('Conservative Temperature CT (°C)')
ax.set_title('T-S diagram')
ax.grid(alpha=0.3)
plt.tight_layout()

# %% [markdown]
# ## 7 — Buoyancy frequency N²

# %%
def compute_N2_profile(dive_df):
    """Compute N² for one dive using gsw.Nsquared."""
    d = dive_df.sort_values('pressure')
    lat = d['lat'].values
    N2, p_mid = gsw.Nsquared(
        d['SA'].values,
        d['CT'].values,
        d['pressure'].values,
        lat=lat,                           # full N-element array
    )
    lat_mid = 0.5 * (lat[:-1] + lat[1:])  # N-1 midpoint lats for z conversion
    z_mid = -gsw.z_from_p(p_mid, lat_mid)
    return N2, z_mid


def plot_N2_profile(df, dive_id):
    d = df[df['dive_id'] == dive_id]
    N2, z_mid = compute_N2_profile(d)

    N2_smooth = gaussian_filter1d(np.maximum(N2, 0), sigma=3)

    fig, ax = plt.subplots(figsize=(5, 7))
    ax.plot(N2_smooth * 1e4, z_mid, color='steelblue', lw=1.5,
            label='N² (×10⁻⁴ s⁻²)')
    ax.axvline(0, color='k', lw=0.8, ls='--')
    ax.set_xlabel('N² (×10⁻⁴ s⁻²)')
    ax.set_ylabel('Depth (m)')
    ax.invert_yaxis()
    ax.set_title(f'Buoyancy frequency — Dive {dive_id}')
    ax.grid(alpha=0.3)
    plt.tight_layout()
    return fig


plot_N2_profile(df, DIVE_TO_PLOT)

# %% [markdown]
# ## 8 — Save figures
#
# Uncomment to export all figures for the report.

# %%
# import os
# os.makedirs('figures', exist_ok=True)
# for i, fig in enumerate(plt.get_fignums()):
#     plt.figure(fig).savefig(f'figures/fig_{i:02d}.pdf', bbox_inches='tight')
